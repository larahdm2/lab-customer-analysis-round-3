# %%
import pandas as pd
import numpy as np

# %%
# 1 Show DataFrame info.

customer = pd.read_csv('marketing_customer_analysis.csv')
customer
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
# 2 Describe DataFrame.

customer.describe().T
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# Months Since Policy Inception     0.000000    24.000000     48.000000
# Number of Open Complaints         0.000000     0.000000      0.000000
# Number of Policies                1.000000     1.000000      2.000000
# Total Claim Amount                0.099007   272.258244    383.945434
#
#                                         75%           max
# Customer Lifetime Value         8962.167041  83325.381190
# Income                         62320.000000  99981.000000
# Monthly Premium Auto             109.000000    298.000000
# Months Since Last Claim           23.000000     35.000000
# Months Since Policy Inception     71.000000     99.000000
# Number of Open Complaints          0.000000      5.000000
# Number of Policies                 4.000000      9.000000
# Total Claim Amount               547.514839   2893.239678

# %%
# 3 Show a plot of the total number of responses.
# As the data is categorical, I´d like to create a pie chart to see the proportions.

# I need 2 lists of the data in the same order. One with yes/no, and other one with the counts.

# Calculate the counts
customer['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
# Create the lists

responses = ['No', 'Yes']
counts = [7826, 1308]

# Show the plot

import matplotlib.pyplot as plt

plt.bar(responses, counts)
# Out:
# <BarContainer object of 2 artists>

# %%
# # Other way

# import matplotlib.pyplot as plt

# # customer['Response'].value_counts().plot(kind='bar') # Without formatting

# # Formatting
# plt.figure(figsize=(8, 6)) # It is not necessary
# plt.xlabel('Response')
# plt.ylabel('Count')
# plt.title('Total Number of Responses')

# customer['Response'].value_counts().plot(kind='bar')
# plt.show()

# %%
# #customer[(customer['Response']=='Yes') & (customer['Sales Channel'])].value_counts()
# customer[(customer['Response']=='Yes')].value_counts()
# Out:
# Customer  State       Customer Lifetime Value  Response  Coverage  Education             Effective To Date  EmploymentStatus  Gender  Income  Location Code  Marital Status  Monthly Premium Auto  Months Since Last Claim  Months Since Policy Inception  Number of Open Complaints  Number of Policies  Policy Type     Policy        Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  Vehicle Size
# AA16582   Washington  24127.504020             Yes       Basic     Bachelor              1/26/11            Medical Leave     M       14072   Suburban       Divorced        71                    13                       3                              0                          2                   Personal Auto   Personal L2   Offer1            Agent          511.200000          Four-Door Car  Medsize         1
# RV14138   Nevada      4334.064096              Yes       Extended  Bachelor              2/27/11            Retired           F       23904   Suburban       Single          123                   1                        67                             3                          1                   Personal Auto   Personal L3   Offer1            Agent          590.400000          SUV            Medsize         1
# SE72928   California  9075.768214              Yes       Basic     Master                1/26/11            Employed          M       37722   Rural          Single          116                   8                        23                             0                          8                   Personal Auto   Personal L1   Offer1            Agent          158.077504          Sports Car     Medsize         1
# SE15781   California  2396.219292              Yes       Basic     Bachelor              1/10/11            Unemployed        F       0       Suburban       Married         66                    6                        71                             2                          1                   Corporate Auto  Corporate L1  Offer2            Call Center    433.160284          Four-Door Car  Large           1
# SD67101   Nevada      3600.934326              Yes       Basic     High School or Below  2/25/11            Retired           F       25147   Suburban       Single          101                   7                        54                             0                          1                   Personal Auto   Personal L2   Offer1            Agent          694.598288          SUV            Medsize         1
#                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# JF83834   Oregon      2491.317024              Yes       Basic     Doctor                1/29/11            Employed          M       36631   Rural          Divorced        62                    30                       77                             0                          1                   Corporate Auto  Corporate L1  Offer1            Agent          67.530904           Four-Door Car  Large           1
# JF36291   California  3873.647046              Yes       Basic     College               1/20/11            Retired           M       28142   Suburban       Married         105                   18                       50                             0                          1                   Personal Auto   Personal L3   Offer2            Agent          701.708239          Sports Car     Medsize         1
# JF25129   California  8509.850887              Yes       Basic     Master                1/31/11            Disabled          M       26057   Suburban       Divorced        74                    3                        63                             0                          2                   Personal Auto   Personal L2   Offer1            Call Center    523.888845          Four-Door Car  Small           1
# JC93010   California  4929.549699              Yes       Basic     Bachelor              1/26/11            Employed          M       25632   Suburban       Married         63                    27                       52                             0                          7                   Personal Auto   Personal L2   Offer2            Call Center    351.270869          Two-Door Car   Medsize         1
# ZZ49347   Oregon      2592.437797              Yes       Basic     High School or Below  1/2/11             Employed          M       72421   Suburban       Married         65                    8                        23                             0                          1                   Personal Auto   Personal L3   Offer2            Call Center    312.000000          Four-Door Car  Small           1
# Length: 1308, dtype: int64

# %%
# 4 Show a plot of the response rate by the sales channel.

# # customer2 = customer[['Sales Channel', 'Response']]

# # customer2[] = customer3[(customer3['Response']=='Yes') & (customer3['Sales Channel'])]
# # customer3

# # customer3 = customer3.reset_index(drop=True)
# # customer3

# # customer3 = customer3.drop(['Response'], axis=1)
# # customer3

# # n_channel = customer3['Sales Channel'].value_counts()
# # n_channel

# # mean_customer3 = n_channel.mean()
# # mean_customer3

# # sales_channel = customer['Sales Channel'].value_counts()
# # response = customer['Response'].value_counts()


# # I need two lists. One with the percentage of responses of each channel, other one with the name of the channels.

# # A rate is between 1 and 0, so if there is a response, I´ll say yes=1, no=0 and see how many each channel has

# responses = []



        
# customer[(custome3['Response']=='Yes') & (customer3['Sales Channel'])]

# sales_channel = []

# for i in customer['Sales Channel']:
#     sales_channel.append(i)

# # plt.scatter(sales_channel, response)
# # plt.show()

# %%
customer2 = customer.set_index('Sales Channel')
customer2.loc[:, ['Response']]
# Out:
#               Response
# Sales Channel
# Agent               No
# Agent               No
# Agent               No
# Call Center         No
# Agent               No
# ...                ...
# Web                 No
# Branch             Yes
# Branch              No
# Branch              No
# Call Center         No
#
# [9134 rows x 1 columns]

# %%
sales_channel = []

for i in customer['Sales Channel']:
    sales_channel.append(i)

responses = []

for i in customer['Response']:
    if i == 'Yes':
        responses.append(1)
    else:
        responses.append(0)

responses

plt.pie(responses, labels=sales_channel, autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[140], line 16
#      12         responses.append(0)
#      14 responses
# ---> 16 plt.pie(responses, labels=sales_channel, autopct='%1.1f%%')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2772, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2765 @_copy_docstring_and_deprecators(Axes.pie)
#    2766 def pie(
#    2767         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2770         textprops=None, center=(0, 0), frame=False,
#    2771         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2772     return gca().pie(
#    2773         x, explode=explode, labels=labels, colors=colors,
#    2774         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2775         labeldistance=labeldistance, startangle=startangle,
#    2776         radius=radius, counterclock=counterclock,
#    2777         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2778         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2779         hatch=hatch, **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3253, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3251 w.set(**wedgeprops)
#    3252 slices.append(w)
# -> 3253 self.add_patch(w)
#    3255 if shadow:
#    3256     # Make sure to add a shadow after the call to add_patch so the
#    3257     # figure and transform props will be set.
#    3258     shad = mpatches.Shadow(w, -0.02, -0.02, label='_nolegend_')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2379, in _AxesBase.add_patch(self, p)
#    2377 if p.get_clip_path() is None:
#    2378     p.set_clip_path(self.patch)
# -> 2379 self._update_patch_limits(p)
#    2380 self._children.append(p)
#    2381 p._remove_method = self._children.remove
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2401, in _AxesBase._update_patch_limits(self, patch)
#    2398 # Get all vertices on the path
#    2399 # Loop through each segment to get extrema for Bezier curve sections
#    2400 vertices = []
# -> 2401 for curve, code in p.iter_bezier(simplify=False):
#    2402     # Get distance along the curve of any extrema
#    2403     _, dzeros = curve.axis_aligned_extrema()
#    2404     # Calculate vertices of start, end and any extrema in between
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:443, in Path.iter_bezier(self, **kwargs)
#     441 first_vert = None
#     442 prev_vert = None
# --> 443 for verts, code in self.iter_segments(**kwargs):
#     444     if first_vert is None:
#     445         if code != Path.MOVETO:
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:416, in Path.iter_segments(self, transform, remove_nans, clip, snap, stroke_width, simplify, curves, sketch)
#     414     for i in range(extra_vertices):
#     415         next(codes)
# --> 416         curr_vertices = np.append(curr_vertices, next(vertices))
#     417 yield curr_vertices, code
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:5444, in append(arr, values, axis)
#    5442     values = ravel(values)
#    5443     axis = arr.ndim-1
# -> 5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# Other way
# Convert 'Response' column to 0s and 1s
# customer['Response'] = customer['Response'].map({'No': 0, 'Yes': 1})

# # Plot the response rate by the sales channel
# plt.figure(figsize=(8, 6))
# response_rate_by_channel = customer.groupby('Sales Channel')['Response'].mean()
# response_rate_by_channel.plot(kind='bar')
# plt.xlabel('Sales Channel')
# plt.ylabel('Response Rate')
# plt.title('Response Rate by Sales Channel')
# plt.show()

# %%
# Show a plot of the response rate by the total claim amount.

# %%
# Task 5: Show a plot of the response rate by the total claim amount

# Create bins for total claim amount
# bins = [0, 500, 1000, 1500, 2000, 2500, 3000, float('inf')]
# labels = ['< $500', '$500 - $1000', '$1000 - $1500', '$1500 - $2000', '$2000 - $2500', '$2500 - $3000', '>$3000']
